# %% [markdown]
# # Introduction
#
# This file will perform a webscrape the mathematics, statistics and computer science articles found on [ArXiv.org](arxiv.org) and the mirror site [xxx.lanl.gov](xxx.lanl.gov).  The program will collect the title, aurthors, subjects and id number in groups of 25.  After getting the information for a group of 25 articles, the program will then read the pdf file using the id number and then store the title, aurthors, subjects, id number and paper in a Mongo database.  For each group of 25 articles, the site will switch between ArXiv and its mirror site to avoid being detected as a bot.
#
#
# For Mongo run
#
# ``` sudo service mongod start ```
#
# on the AWS Machine and
#
# ```ssh -i .ssh/aws_key.pem -NL 12345:localhost:27017 ubuntu@YOUR-IP-ADDRESS```
#
# on my machine

# %%
import requests
from bs4 import BeautifulSoup
import bs4

import numpy as np
import pandas as pd

import re

from io import BytesIO

from pdfminer.pdfinterp import PDFResourceManager, PDFPageInterpreter
from pdfminer.converter import HTMLConverter,TextConverter,XMLConverter
from pdfminer.layout import LAParams
from pdfminer.pdfpage import PDFPage
import pdfminer

from pymongo import MongoClient

import time

# %%
packages = (('Requests',requests),('Beautiful Soup',bs4), ('Numpy',np),
               ('Pandas',pd),('Regex',re),('pdfminer',pdfminer))

for package in packages:
    print('{0} version: {1}'.format(package[0],package[1].__version__))
    
# !Python -V
# Out:
# Requests version: 2.18.4
# Beautiful Soup version: 4.6.0
# Numpy version: 1.14.1
# Pandas version: 0.22.0
# Regex version: 2.2.1
# pdfminer version: 20170720
# Python 3.6.4 :: Anaconda custom (64-bit)

# %% [markdown]
# ## Mongo Set Up

# %%
client = MongoClient(port=12345) # this is the port set by the SSH tunnel
db = client.research_papers

# %%
db.collection_names()
# Out:
# ['cs_papers', 'math_papers', 'stat_papers']

# %%
collections = {'stat':db.stat_papers, 'cs':db.cs_papers}
# collections = {'cs':db.cs_papers, 'stat':db.stat_papers, 'math':db.math_papers}
topics = collections.keys()

# %% [markdown]
# I am going to take the papers from 2017.  For the subjects mathematics, statistics and computer science there are approximatley 34k, 49k and 27k papers, respectively.  I wrote the code to be able to easily expand to more years.
#
# As it turns out, taking the papers for all of 2017 in a short time period was a bit optimistic...I was able to collect some papers for the first few months...

# %%
year = np.char.array(['07','08','09','10','11','12','13','14','15','16','17'])
month = np.char.array(['01','02','03','04','05','06','07','08','09','10','11','12'])

years, months = np.meshgrid(year,month)
years = years.flatten()
months = months.flatten()

url_date = years+months
url_date = sorted(url_date)
url_date = url_date[-12:]

# %% [markdown]
# The website doesn't produce an error message when skipping past the total number of articles, it just repeats the final n number of articles.  To give the algorithm a stopping point, I will find the total number of articles.

# %%
def Get_Num_Articles(soup):
    '''Returns the total number of articles for the given topic.'''
    pages = []

    link_string = re.compile('/list/(.*)')

    for html in soup.find_all('a'):
        html_attrs = html.attrs
        try: 
            if re.match(link_string,html['href']):
                page_range = html.text
                if '-' in page_range:
                    page_range = page_range.split('-')
                    page = page_range[1]
                    page = int(page)
                    pages.append(page)
        except:
            None

    return max(pages)

# %% [markdown]
# Collecting all of the ids stored in the database, so the program can quickly check and ignore papers I already downloaded.  This came about because of some issues with storing the data.

# %%
all_ids = np.array([])

for database in [db.cs_papers, db.stat_papers, db.math_papers]:
    math_papers = db.cs_papers
    all_papers = []
    current_paper = math_papers.find()

    for pape in current_paper:    
        id_ = pape['_id']
        all_ids = np.append(all_ids, id_)
        
len(all_ids)
# Out:
# 1959

# %% [markdown]
# # Article Class
#
# (That's right, I made a class.  I'm probably the best programmer ever!)
#
# The metadata on each page has the following information:
# 1. Title
# 2. Aurthors
# 3. Comments
# 4. Subjects
# 5. Paper ID
# 6. Journal Reference
#
# When obtaining the data, the aurthors of a paper are split into multiple lists.  The code will extract the title, subject and comments from the list and the remaining of the list will be the author.  The code will separatly pull the pdf information, if it is availible.  Some articles do not have pdf links, so I will obtain all of the information for each article from the main page and then delete the ones from the list that do not have a pdf file.

# %%
class Article:
    def __init__(self, article_info, pdf_url, url_head):
        global all_ids
        
        self._url_head = url_head
        self.article_info = self.get_article_info(article_info)
        self.title = self.get_title()
        self.subject = self.get_subjects()
        self.author = self.get_authors()
        self.article_id = self.get_article_id(pdf_url)
        
        if self.article_id not in all_ids:
            self.abstract = self.get_abstract()
            self.article = self.get_article()
            all_ids = np.append(all_ids, self.article_id)
        else:
            self.abstract = None
            self.article = None
            
        self.mongo = self.mongodb_form()
    
    def get_article_info(self, article_info):
        '''
            Takes the text from the initital article information, convert
            to a list and make all lower case.
        '''
        
        article_info = article_info.text.strip()

        article_info = article_info.lower()

        enter_char = re.compile(r'\n')
        article_info = re.split(enter_char, article_info)

        while '' in article_info:
            article_info.remove('')
        
        return article_info

    def get_title(self):
        '''
            First checks to see if the title is given in the metadata page,
            if the title is not given it will return None and the unaltered
            article information list, otherwise it will remove the title from
            the article information list and return the title. Furthermore, 
            the title is given in the form 'Title: I am a title.' This function 
            will return just the title.
        ''' 
        
        no_title = True
        index = 0

        while no_title and index < len(self.article_info):
            ai = self.article_info[index]
            if 'title' in ai:
                no_title = False
            else:
                index+=1

        if no_title:
            return None

        else:
            title = self.article_info.pop(index)

            return title[7:]

    def get_subjects(self):
        '''
            First checks to see if the subjects are given in the metadata page,
            if the subjects were not given it will return None and the unaltered
            article information list, otherwise it will remove the subjects from
            the article information list and return a list of the subjects.
            Furthermore, the subjects are given in the form Subject: subject 1 (ss.S1);
            subject 2 (ss.S2).  This function will return a list containing all 
            subjects and topics that are either math, cs (computer science) or stat 
            in the form ss.SS.
        ''' 
        
        no_subjects = True
        index = 0

        while no_subjects and index < len(self.article_info):
            ai = self.article_info[index]
            if 'subject' in ai:
                no_subjects = False
            else:
                index+=1

        if no_subjects:
            return None

        else:
            subjects = self.article_info.pop(index)
            subjects = subjects[10:]

            subjects = subjects.split('; ')

            relevant_subjects = []

            for index, sub in enumerate(subjects):
                par_char = re.compile(r'\(.*\)')
                find_par = re.search(par_char,sub)
                find_par = find_par[0]
                find_par = find_par[1:-1]

                find_par_split = find_par.split('.')
                
                if len(find_par_split) == 1:
                    find_par_split = find_par.split('-')
                    topic, subject = find_par_split
                    
                elif len(find_par_split) == 2:
                    topic, subject = find_par_split
                    
                else:
                    print('-'*50 + ' '*5 + find_par + ' '*5 + '-'*50)
                    topic = 'cs'
                
                if topic in topics:
                    relevant_subjects.append(find_par)
            
            return relevant_subjects

    def remove_comments(self):
        '''
            First checks to see if there are comments given in the metadata page,
            if the comments were given it will remove the comments from the 
            article information list.
        ''' 
        
        no_comments = True
        index = 0

        while no_comments and index < len(self.article_info):
            ai = self.article_info[index]
            
            if 'comment' in ai:
                no_comments = False
                
            else:
                index+=1

        if not no_comments:
            self.article_info.pop(index)
            
    def remove_journal_ref(self):
        '''
            First checks to see if there are journal references given in the 
            metadata page, if there are journal references were given it 
            will remove the them from the article information list.
        ''' 
        
        no_journal_ref = True
        index = 0

        while no_journal_ref and index < len(self.article_info):
            ai = self.article_info[index]
            
            if 'journal-ref' in ai:
                no_journal_ref = False
                
            else:
                index+=1

        if not no_journal_ref:
            self.article_info.pop(index)
    

    def get_authors(self):
        '''
            First removes the comments from the metadata page, then
            checks to see if the authors are given in the metadata page,
            if the authors were not given it will return None otherwise it 
            will return a list of the authors. Furthermore, the authors are 
            given in a list in the form ['Author 1, ', 'Author 2, ', 'Author 3'],
            this code will remove the comma and extra space at the end.
        ''' 
        
        self.remove_comments()
        self.remove_journal_ref()
        
        no_authors = True
        index = 0

        while no_authors and index < len(self.article_info):
            ai = self.article_info[index]
            
            if 'author' in ai:
                no_authors = False
                
            else:
                index+=1

        if no_authors:
            return None

        else:
            self.article_info.pop(index)
            authors = []

            comma_space = re.compile(', ')

            for author in self.article_info:
                author = re.sub(comma_space, '', author)
                authors.append(author)

        return authors
        
    def get_article_id(self, pdf_url):
        '''Pulls the article id from the pdf information.'''
        
        pdf_link_string = re.compile('/pdf/(.*)')

        for pu in pdf_url.find_all('a'):
            try:
                if re.match(pdf_link_string,pu['href']):
                    pu = pu['href']

                    # takes the number for the pdf file
                    pu = pu[5:]
                    return pu
            except:
                None
                
        return None
    
    def convert_pdf(self,need_to_convert):
        '''Converts the content of the website from Bytes to text.'''
        
        try:
            manager = PDFResourceManager() 
            codec = 'utf-8'
            caching = True

            output = BytesIO()
            converter = TextConverter(manager, output, codec=codec, laparams=LAParams())

            interpreter = PDFPageInterpreter(manager, converter)   
            infile = BytesIO(need_to_convert)

            for page in PDFPage.get_pages(infile,caching=caching, check_extractable=True):
                interpreter.process_page(page)

            convertedPDF = output.getvalue()  

            infile.close(); converter.close(); output.close()

            return convertedPDF
        except:
            return None
    
    def initial_cleaning(self, text):
        '''
            Cleans the text by fixing the words that are separated by spaces, removing
            punctuation, removing numbers, making all lower-case, removing excess 
            spacing, and (attempting) to start after the last author.
        '''
        
        punc = r"-\n|!|\"|#|$|%|&|\'|\(|\)|\*|\+|,|-|\.|/|:|;|<|=|>|\?|@|\[|\\|\]|\^|_|\`|\{|\||\}|~|[0-9]+"
        things_to_drop = re.compile(punc)
        text = re.sub(things_to_drop, '', text)

        enters = re.compile(r'\n')
        text = re.sub(enters,' ',text)
        text = re.sub('\s+', ' ', text).strip()
        text = text.lower()

        last_author = re.sub(things_to_drop,'',self.author[-1])

        author_search = re.search(last_author, text)
        
        try:
            start = author_search.span()[1]+1
            text = text[start:]
            
        except:
            None
        
        return text
    
    def get_abstract(self):
        '''
            Uses the article id to go to the abstract page, pulls the 
            abtract then uses initial cleaning to clean it.
        '''
        abstract_url = self._url_head + '/abs/' + self.article_id
        
        abs_response = requests.get(abstract_url)
        text = abs_response.text

        soup = BeautifulSoup(text,'lxml')
        
        try:
            abstract = soup.find('blockquote').text
            abstract = abstract[11:]

            return self.initial_cleaning(abstract)
        
        except:
            None
        
        return None
    
    def get_article(self):
        '''
            Uses the article id to get the pdf document.  Once the reader
            reads the pdf document it will send it to convert_pdf which 
            will convert the PDF to text.
        '''

        pdf_url = self._url_head + '/pdf/' + self.article_id
        
        attempts = 0
        convertedPDF = None
        
        while (attempts < 10) & (not convertedPDF):
            pdf_response = requests.get(pdf_url)

            convertedPDF = self.convert_pdf(pdf_response.content)
            time.sleep(10)
            
            attempts +=1
        
        if not convertedPDF:
            return None
            print('bad: ',article.title)
        
        else:
            soup = BeautifulSoup(convertedPDF,'lxml')
            
            return self.initial_cleaning(soup.text)
        
   
    def mongodb_form(self):
        '''
            Converts the data into a dictionary to be stored in
            a Mongo database.
        '''
        mongo = {}
        mongo['title'] = self.title
        mongo['subject'] = self.subject
        mongo['author'] = self.author
        mongo['_id'] = self.article_id
        mongo['abstract'] = self.abstract
        mongo['article'] = self.article
        
        return mongo

# %% [markdown]
# # Data Scrape (aka The Most Painful Part)

# %%
for date in url_date[2:]:
    print(date)
    
    max_pages = 1500
    skip = 595
    
    while skip < max_pages:

        for topic in topics:
            
            col = collections[topic]

            # alernating between the site and the mirrored site to avoid being
            # banned.
            if skip // 2 == 0:
                url_head = 'https://arxiv.org' 
            else: 
                url_head = 'http://xxx.lanl.gov'
                
            url = url_head + '/list/' + topic + '/' + date +'?skip=' + str(skip) + '&show=25'
            
            response = requests.get(url)
            site_text = response.text

            soup = BeautifulSoup(site_text,'lxml')
            
#             if skip == 0:
#                 max_pages = Get_Num_Articles(soup)

            # All articles' information is sandwiched between dd's
            article_information = soup.find_all('dd')

            # All pdf information is sandwiched between dt's
            pdf_information = soup.find_all('dt')

            for index, pdf in enumerate(pdf_information):
                if 'pdf' in pdf.text:

                    a_info = article_information[index]
                    
                    try:
                        # for running over night
                        article = Article(a_info, pdf, url_head)

                    except:
                        None
                        
                    if article.article:
                        col.insert_one(article.mongo)
                                
            print('Topic: {0}, Skipping: {1}'.format(topic,skip))

        skip += 25
# Out:
# 1703
# mongoed: a short note on almost sure convergence of bayes factors in the general  set-up
# mongoed: an algorithm for removing sensitive information: application to  race-independent recidivism prediction
# mongoed: predicting with limited data - increasing the accuracy in vis-nir  diffuse reflectance spectroscopy by smote
# mongoed: tuning free orthogonal matching pursuit
# mongoed: optimal graphon estimation in cut distance
# mongoed: do pay-for-performance incentives lead to a better health outcome?
# mongoed: quantile treatment effects in the regression kink design
# mongoed: bergm: bayesian exponential random graph models in r
# mongoed: one-sided cross-validation for nonsmooth density functions
# mongoed: bayesian adaptive bandit-based designs using the gittins index for  multi-armed trials with normally distributed endpoints
# mongoed: student-t process quadratures for filtering of non-linear systems with  heavy-tailed noise
# mongoed: growing simplified vine copula trees: improving dißmann's algorithm
# mongoed: understanding the probabilistic latent component analysis framework
# mongoed: smooth image-on-scalar regression for brain mapping
# mongoed: on optimal experimental designs for sparse polynomial chaos expansions
# mongoed: generalised additive mixed models for dynamic analysis in linguistics: a  practical introduction
# mongoed: cost-complexity pruning of random forests
# mongoed: minimax regret bounds for reinforcement learning
# mongoed: an induced natural selection heuristic for evaluating optimal bayesian  experimental designs
# mongoed: clustering of gamma-ray bursts through kernel principal component  analysis
# mongoed: nonparametric intensity estimation from indirect point process  observations under unknown error distribution
# mongoed: end-to-end learning for structured prediction energy networks
# mongoed: gaussian process regression for forecasting battery state of health
# mongoed: the beta flexible weibull distribution
# Topic: stat, Skipping: 195
# mongoed: general and robust communication-efficient algorithms for distributed  clustering
# mongoed: autonomous skill-centric testing using deep learning
# mongoed: meta networks
# mongoed: slim: semi-lazy inference mechanism for plan recognition
# mongoed: towards cnn map compression for camera relocalisation
# mongoed: exact topology reconstruction of radial dynamical systems with  applications to distribution system of the power grid
# mongoed: wireless node cooperation with resource availability constraints
# mongoed: learning the structure of generative models without labeled data
# mongoed: araguaia medical vision lab at isic 2017 skin lesion classification  challenge
# mongoed: friendship maintenance and prediction in multiple social networks
# mongoed: binarized convolutional landmark localizers for human pose estimation  and face alignment with limited resources
# mongoed: using synthetic data to train neural networks is model-based reasoning
# mongoed: an efficient algorithm for finding all possible input nodes for  controlling complex networks
# mongoed: how to escape saddle points efficiently
# mongoed: being robust (in high dimensions) can be practical
# mongoed: adapting the dmtcp plugin model for checkpointing of hardware emulation
# mongoed: addendum to "a market framework for eliciting private data"
# mongoed: improved deterministic distributed matching via rounding
# mongoed: depth estimation using modified cost function for occlusion handling
# mongoed: workload analysis of blue waters
# mongoed: on the asymptotic behavior of the price of anarchy: is selfish routing  bad in highly congested networks?
# mongoed: atomic norm minimization for modal analysis from random and compressed  samples
# mongoed: on the fine-grained complexity of one-dimensional dynamic programming
# Topic: cs, Skipping: 195
# mongoed: distributed multi-speaker voice activity detection for wireless acoustic  sensor networks
# mongoed: incorporating covariates into integrated factor analysis of multi-view  data
# mongoed: a new sample-based algorithms to compute the total sensitivity index
# mongoed: adaptivity to noise parameters in nonparametric active learning
# mongoed: causal inference through the method of direct estimation
# mongoed: quantifying the causal effect of speed cameras on road traffic accidents  via an approximate bayesian doubly robust estimator
# mongoed: a tutorial on bridge sampling
# mongoed: the use of spatial information in entropy measures
# mongoed: modeling spatial processes with unknown extremal dependence class
# mongoed: block cur : decomposing large distributed matrices
# mongoed: propensity score weighting for causal inference with clustered data
# mongoed: analysis of the gibbs sampler for gaussian hierarchical models via  multigrid decomposition
# mongoed: modeling relational data with graph convolutional networks
# mongoed: nonconvex one-bit single-label multi-label learning
# mongoed: generalised reichenbachian common cause systems
# mongoed: inference via low-dimensional couplings
# mongoed: an mcmc-free approach to post-selective inference
# mongoed: scalable methods for bayesian selective inference
# mongoed: on consistency of graph-based semi-supervised learning
# mongoed: sequential monte carlo methods in the nimble r package
# mongoed: deciding how to decide: dynamic routing in artificial neural networks
# mongoed: a unified treatment of multiple testing with prior knowledge using the  p-filter
# mongoed: identifying the support of rectangular signals in gaussian noise
# mongoed: multi-fidelity bayesian optimisation with continuous approximations
# Topic: stat, Skipping: 220
# mongoed: dawt: densely annotated wikipedia texts across multiple languages
# mongoed: performance analysis of a hybrid downlink-uplink cooperative noma scheme
# mongoed: a laplacian framework for option discovery in reinforcement learning
# mongoed: scaling up the software development process, a case study highlighting  the complexities of large team software development
# mongoed: eliciting private user information for residential demand response
# mongoed: hedging strategies for load-serving entities in wholesale electricity  markets
# mongoed: compositional falsification of cyber-physical systems with machine  learning components
# mongoed: how peer effects influence energy consumption
# mongoed: asap: prioritizing attention via time series smoothing
# mongoed: belief propagation in conditional rbms for structured prediction
# mongoed: optimization of distributions differences for classification
# mongoed: a comparative study of word embeddings for reading comprehension
# mongoed: scalable deep traffic flow neural networks for urban traffic congestion  prediction
# mongoed: optimal time and space construction of suffix arrays and lcp arrays for  integer alphabets
# mongoed: online popularity under promotion: viral potential, forecasting, and the  economics of time
# mongoed: active learning for cost-sensitive classification
# mongoed: exponential moving average model in parallel speech recognition training
# mongoed: a novel multi-task deep learning model for skin lesion segmentation and  classification
# mongoed: unsupervised basis function adaptation for reinforcement learning
# mongoed: outlier cluster formation in spectral clustering
# mongoed: deeply aggrevated: differentiable imitation learning for sequential  prediction
# mongoed: ultra-dense edge caching under spatio-temporal demand and network  dynamics
# Topic: cs, Skipping: 220
# mongoed: unsupervised learning of mixture regression models for longitudinal data
# mongoed: spectrum estimation from a few entries
# mongoed: analysis of error control in large scale two-stage multiple hypothesis  testing
# mongoed: an initial study on load forecasting considering economic factors
# mongoed: probabilistic models for daily peak loads at distribution feeders
# mongoed: penalized pairwise pseudo likelihood for variable selection with  nonignorable missing data
# mongoed: spectral analysis of stationary random bivariate signals
# mongoed: multivariate functional data visualization and outlier detection
# mongoed: practical coreset constructions for machine learning
# mongoed: universal consistency and robustness of localized support vector  machines
# mongoed: a controlled set-up experiment to establish personalized baselines for  real-life emotion recognition
# mongoed: using maximum entry-wise deviation to test the goodness-of-fit for  stochastic block models
# mongoed: unifying approach to selective inference with applications to  cross-validation
# mongoed: dual lasso selector
# mongoed: a new class of discrete-time stochastic volatility model with correlated  errors
# mongoed: asymptotic performance of pca for high-dimensional heteroscedastic data
# mongoed: variational inference for probabilistic poisson pca
# mongoed: copula index for detecting dependence and monotonicity between  stochastic signals
# mongoed: analysing the sensitivity of pollen based land-cover maps to different  auxiliary variables
# mongoed: efficient variational bayesian neural network ensembles for outlier  detection
# mongoed: a continuous spatio-temporal approach to estimate climate change
# mongoed: worth weighting? how to think about and use weights in survey  experiments
# mongoed: the geometry of hypothesis testing over convex cones: generalized  likelihood tests and minimax radii
# mongoed: ratingscalereduction package: stepwise rating scale item reduction  without predictability loss
# mongoed: counterfactual fairness
# Topic: stat, Skipping: 245
# mongoed: large-scale evolution of image classifiers
# mongoed: on preserving observation properties of the reduced supervisor in  discrete-event systems
# mongoed: on coparanormality in distributed supervisory control of discrete-event  systems
# mongoed: optimal non-blocking decentralized supervisory control using g-control  consistency
# mongoed: deconvolving feedback loops in recommender systems
# mongoed: when hashes met wedges: a distributed algorithm for finding high  similarity vectors
# mongoed: full-duplex operations in wireless powered communication networks
# mongoed: on the security of warning message dissemination in vehicular ad hoc  networks
# mongoed: étude sur les portails et agrégateurs des ressources pédagogiques  universitaires francophones en accès libre
# mongoed: on the presence of green and sustainable software engineering in higher  education curricula
# mongoed: good cyclic codes and the uncertainty principle
# mongoed: sequential plan recognition
# mongoed: arbitrary-oriented scene text detection via rotation proposals
# mongoed: zero-delay source-channel coding with a one-bit adc front end and  correlated side information at the receiver
# mongoed: an intracardiac electrogram model to bridge virtual hearts and  implantable cardiac devices
# mongoed: deep artifact learning for compressed sensing and parallel mri
# mongoed: on parameterized complexity of group activity selection problems on  social networks
# mongoed: first-order logic with counting: at least, weak hanf normal forms always  exist and can be computed!
# mongoed: on the behavior of convolutional nets for feature extraction
# mongoed: deep learning with domain adaptation for accelerated  projection-reconstruction mr
# mongoed: multiplicative weights update with constant step-size in congestion  games: convergence, limit cycles and chaos
# mongoed: dynamic state warping
# mongoed: symmetric laplacians, quantum density matrices and their von-neumann  entropy
# Topic: cs, Skipping: 245
# mongoed: application of backpropagation neural networks to both stages of  fingerprinting based wips
# mongoed: scalpel: extracting neurons from calcium imaging data
# mongoed: nuisance parameter based sample size re-estimation incorporating prior  information
# mongoed: learning to generate samples from noise through infusion training
# mongoed: a conditional density estimation partition model using logistic gaussian  processes
# mongoed: new reconstruction and data processing methods for regression and  interpolation analysis of multidimensional big data
# mongoed: a simple online parameter estimation technique with asymptotic  guarantees
# mongoed: the minimum distance estimation with multiple integral in panel data
# mongoed: stochastic primal dual coordinate method with non-uniform sampling based  on optimality violations
# mongoed: bayesian nonparametric inference for m/g/1 queueing systems
# mongoed: mri-based surgical planning for lumbar spinal stenosis
# mongoed: on parameters transformations for emulating sparse priors using  variational-laplace inference
# mongoed: a deterministic global optimization method for variational inference
# mongoed: overcoming model simplifications when quantifying predictive uncertainty
# mongoed: gibbs reference posterior for robust gaussian process emulation
# mongoed: sufficient dimension reduction via random-partitions for large-p-small-n  problem
# mongoed: statistical topology and the random interstellar medium
# mongoed: convergence rates in the central limit theorem for weighted sums of  bernoulli random fields
# mongoed: from safe screening rules to working sets for faster lasso-type solvers
# mongoed: targeting bayes factors with direct-path non-equilibrium thermodynamic  integration
# mongoed: logitboost autoregressive networks
# mongoed: testing and learning on distributions with symmetric noise invariance
# mongoed: effect fusion using model-based clustering
# mongoed: deep exploration via randomized value functions
# Topic: stat, Skipping: 270
# mongoed: why is it hard to beat $o(n^2)$ for longest common weakly increasing  subsequence?
# mongoed: runtime optimization of join location in parallel data management  systems
# mongoed: a note on minimum linear arrangement for bc graphs
# mongoed: feudal networks for hierarchical reinforcement learning
# mongoed: nonlinear model predictive control for multi-micro aerial vehicle robust  collision avoidance
# mongoed: efficient network measurements through approximated windows
# mongoed: a survey on content-aware video analysis for sports
# mongoed: multicast transmissions in directional mmwave communications
# mongoed: tree notation: an antifragile program notation
# mongoed: why smart appliances may result in a stupid energy grid?
# mongoed: learning identifiable gaussian bayesian networks in polynomial time and  sample complexity
# mongoed: everware toolkit. supporting reproducible science and challenge-driven  education
# mongoed: parallel energy-stable phase field crystal simulations based on domain  decomposition methods
# mongoed: stochastic separation theorems
# mongoed: custom hypergraph categories via generalized relations
# mongoed: preserving confidentiality in the gaussian broadcast channel using  compute-and-forward
# mongoed: emotionet challenge: recognition of facial expressions of emotion in the  wild
# mongoed: the universal fragment of presburger arithmetic with unary uninterpreted  predicates is undecidable
# mongoed: learning graphical games from behavioral data: sufficient and necessary  conditions
# mongoed: denoising adversarial autoencoders
# mongoed: secure and reconfigurable network design for critical information  dissemination in the internet of battlefield things (iobt)
# mongoed: a simple dynamic model for aggressive, near-limits trajectory planning
# mongoed: context aware query image representation for particular object retrieval
# Topic: cs, Skipping: 270
# mongoed: mimix: a bayesian mixed-effects model for microbiome data from designed  experiments
# mongoed: sample and computationally efficient learning algorithms under s-concave  distributions
# mongoed: testing for the equality of two distributions on high dimensional object  spaces
# mongoed: robust kronecker-decomposable component analysis for low-rank modeling
# mongoed: cross-validation with confidence
# mongoed: data driven exploratory attacks on black box classifiers in adversarial  domains
# mongoed: perspective: energy landscapes for machine learning
# mongoed: an adapted loss function for censored quantile regression
# mongoed: distribution of gaussian process arc lengths
# mongoed: profiled deviance for the multivariate linear mixed-effects model  fitting
# mongoed: dynamic bernoulli embeddings for language evolution
# mongoed: robustness of maximum correntropy estimation against large outliers
# mongoed: reducing crowdsourcing to graphon estimation, statistically
# mongoed: flexible multi-state models for interval-censored data: specification,  estimation, and an application to ageing research
# mongoed: training gaussian mixture models at scale via coresets
# mongoed: alternating optimization for gxe modelling with weighted genetic and  environmental scores: examples from the mavan study
# mongoed: a recursive point process model for infectious diseases
# mongoed: the dependence of machine learning on electronic medical record quality
# mongoed: the multi-armed bandit problem: an efficient non-parametric solution
# mongoed: nonparametric bayesian analysis for support boundary recovery
# mongoed: modeling and estimation for self-exciting spatio-temporal models of  terrorist activity
# mongoed: multiscale granger causality
# mongoed: regsem: regularized structural equation modeling
# mongoed: rejection-free ensemble mcmc with applications to factorial hidden  markov models
# Topic: stat, Skipping: 295
# mongoed: augmented reality for depth cues in monocular minimally invasive surgery
# mongoed: incident light frequency-based image defogging algorithm
# mongoed: virtual vs. real: trading off simulations and physical experiments in  reinforcement learning with bayesian optimization
# mongoed: the global optimization geometry of low-rank matrix optimization
# mongoed: model checking cyber-physical systems using particle swarm optimization
# mongoed: ex2: exploration with exemplar models for deep reinforcement learning
# mongoed: percentile policies for tracking of markovian random processes with  asymmetric cost and observation
# mongoed: on squares of cyclic codes
# mongoed: actor-critic reinforcement learning with simultaneous human control and  feedback
# mongoed: downlink cellular network analysis with los/nlos propagation and  elevated base stations
# mongoed: an extended consideration of joint exploration and tracking: jet
# mongoed: investcoin: a system for privacy-preserving investments
# mongoed: a layered architecture for erasure-coded consistent distributed storage
# mongoed: on the miso channel with feedback: can infinitely massive antennas  achieve infinite capacity?
# mongoed: intensionality, intensional recursion, and the gödel-löb axiom
# mongoed: instance flow based online multiple object tracking
# mongoed: bridging saliency detection to weakly supervised object detection based  on self-paced curriculum learning
# mongoed: an ordered approach to solving parity games in quasi polynomial time and  quasi linear space
# mongoed: defining domain-independent discovery informatics
# mongoed: count-based exploration with neural density models
# mongoed: secure virtual network embedding in a multi-cloud environment
# mongoed: coverage of author identifiers in web of science and scopus
# mongoed: decoupled block-wise ilu(k) preconditioner on gpu
# Topic: cs, Skipping: 295
# mongoed: data-mining textual responses to uncover misconception patterns
# mongoed: the inner structure of time-dependent signals
# mongoed: binarsity: a penalization for one-hot encoded features
# mongoed: lanova penalization for unreplicated data
# mongoed: random sampling of latin squares via binary contingency tables and  probabilistic divide-and-conquer
# mongoed: exact spike train inference via $\ell_0$ optimization
# mongoed: the new concepts of measurement error's regularities and effect  characteristics
# mongoed: full likelihood inference for max-stable data
# mongoed: statistical and computational tradeoff in genetic algorithm-based  estimation
# mongoed: extending growth mixture models using continuous non-elliptical  distributions
# mongoed: learning to predict: a fast re-constructive method to generate  multimodal embeddings
# mongoed: clustering and variable selection in the presence of mixed variable  types and missing data
# mongoed: multivariate regression with gross errors on manifold-valued data
# mongoed: testing independence with high-dimensional correlated samples
# mongoed: finite mixtures of skewed matrix variate distributions
# mongoed: modeling high dimensional multichannel brain signals
# mongoed: a scale free algorithm for stochastic bandits with bounded kurtosis
# mongoed: thompson sampling for linear-quadratic control problems
# mongoed: multilabel classification with r package mlr
# mongoed: value of information: sensitivity analysis and research design in  bayesian evidence synthesis
# mongoed: on the limit imbalanced logistic regression by binary predictors
# mongoed: detection of spatiotemporally coherent rainfall anomalies using markov  random fields
# mongoed: bayesian repulsive gaussian mixture model
# mongoed: a numerical method for the estimation of time-varying parameter models  in large dimensions
# mongoed: sparse multi-output gaussian processes for medical time series  prediction
# Topic: stat, Skipping: 320
# mongoed: multi-step reinforcement learning: a unifying algorithm
# mongoed: on the automated planning and design of smatv systems
# mongoed: towards monetary incentives in social q&a services
# mongoed: contextual multi-armed bandits under feature uncertainty
# mongoed: collusion-resistant and privacy-preserving p2p multimedia distribution  based on recombined fingerprinting
# mongoed: approximate convex hulls: sketching the convex hull using curvature
# mongoed: generalised discount functions applied to a monte-carlo aimu  implementation
# mongoed: first and second order asymptotics in covert communication with  pulse-position modulation
# mongoed: axiomatic attribution for deep networks
# mongoed: a synthetic statistical mimo plc channel model applied to an in-home  scenario
# mongoed: learning styles: literature versus machine learning
# mongoed: internalization of externalities in interdependent security: large  network cases
# mongoed: multi-scale wavelet domain residual learning for limited-angle ct  reconstruction
# mongoed: looking at outfit to parse clothing
# mongoed: understanding and predicting delay in reciprocal relations
# mongoed: sparse depth sensing for resource-constrained robots
# mongoed: skin lesion classification using deep multi-scale convolutional neural  networks
# mongoed: convex recovery of continuous domain piecewise constant images from  non-uniform fourier samples
# mongoed: real-time trajectory replanning for mavs using uniform b-splines and a  3d circular buffer
# Topic: cs, Skipping: 320
# mongoed: multi-sensor transmission management for remote state estimation under  coordination
# mongoed: two-part models with stochastic processes for modelling longitudinal  semicontinuous data: computationally efficient inference and modelling the  overall marginal mean
# mongoed: pwls-ultra: an efficient clustering and learning-based approach for  low-dose 3d ct image reconstruction
# mongoed: sticking the landing: simple, lower-variance gradient estimators for  variational inference
# mongoed: biologically inspired protection of deep networks from adversarial  attacks
# mongoed: fairness in criminal justice risk assessments: the state of the art
# mongoed: band depths based on multiple time instances
# mongoed: cluster validation by measurement of clustering characteristics relevant  to the user
# mongoed: massive-scale estimation of exponential-family random graph models with  local dependence
# mongoed: implementing monte carlo tests with p-value buckets
# mongoed: useful redundancy in parameter and time delay estimation for  continuous-time models
# mongoed: an analysis of the sparseva estimate for the finite sample data case
# mongoed: exact computation of gmm estimators for instrumental variable quantile  regression models
# mongoed: solving non-parametric inverse problem in continuous markov random field  using loopy belief propagation
# mongoed: the cramér-rao inequality on singular statistical models i
# mongoed: polling bias and undecided voter allocations: us presidential elections,  2004 - 2016
# mongoed: index of environmental awareness in russia - mimic approaches for  different economic situations
# mongoed: discovering explainable latent covariance structure for multiple time  series
# mongoed: a bayesian nonparametric approach to log-concave density estimation
# mongoed: robust estimators for generalized linear models with a dispersion  parameter
# mongoed: algebraic variety models for high-rank matrix completion
# mongoed: an orthogonal basis expansion method for solving path-independent  stochastic differential equations
# mongoed: sampling errors in nested sampling parameter estimation
# mongoed: unifying the stochastic spectral descent for restricted boltzmann  machines with bernoulli or gaussian inputs
# Topic: stat, Skipping: 345
# mongoed: soft pneumatic gelatin actuator for edible robotics
# mongoed: deep matching prior network: toward tighter multi-oriented text  detection
# mongoed: building interoperable and cross-domain semantic web of things  applications
# mongoed: noncoherent analog network coding using ldpc-coded fsk
# mongoed: automated top view registration of broadcast football videos
# mongoed: on the set of optimal homeomorphisms for the natural pseudo-distance  associated with the lie group s^1
# mongoed: towards parallel boolean functional synthesis
# mongoed: algebraic geometry codes with complementary duals exceed the asymptotic  gilbert-varshamov bound
# mongoed: query expansion based on crowd knowledge for code search
# mongoed: rosf: leveraging information retrieval and supervised learning for  recommending code snippets
# mongoed: learning deep matrix representations
# mongoed: chain-nn: an energy-efficient 1d chain architecture for accelerating  deep convolutional neural networks
# mongoed: adversarial generation of real-time feedback with neural networks for  simulation-based training
# mongoed: addressing appearance change in outdoor robotics with adversarial domain  adaptation
# mongoed: generative compression
# mongoed: finding influentials in twitter: a temporal influence ranking model
# mongoed: scientific wealth and inequality within nations
# mongoed: sharp bounds for population recovery
# mongoed: 4/3 rectangle tiling lower bound
# mongoed: tracing networks of knowledge in the digital age
# mongoed: lexical resources for hindi marathi mt
# mongoed: i would not plant apple trees if the world will be wiped: analyzing  hundreds of millions of behavioral records of players during an mmorpg beta  test
# mongoed: minimizing latency for secure distributed computing
# mongoed: machine learning friendly set version of johnson-lindenstrauss lemma
# Topic: cs, Skipping: 345
# mongoed: particle filtering for plca model with application to music  transcription
# mongoed: deep scattering transform applied to note onset detection and instrument  recognition
# mongoed: multiple testing when many $p$-values are uniformly conservative, with  application to testing qualitative interaction in educational interventions
# mongoed: reply to cox et al. and kessler et al.: data and code sharing is the way  forward for fmri
# mongoed: gradient-based regularization parameter selection for problems with  non-smooth penalty functions
# mongoed: modular bayes screening for high-dimensional predictors
# mongoed: adaptive gaussian process approximation for bayesian inference with  expensive likelihood functions
# mongoed: riemannian gaussian distributions on the space of positive-definite  quaternion matrices
# mongoed: marginal likelihood based model comparison in fuzzy bayesian learning
# mongoed: estimable group effects for strongly correlated variables in linear  models
# mongoed: improving spectral clustering using the asymptotic value of the  normalised cut
# mongoed: spatially-dependent multiple testing under model misspecification, with  application to detection of anthropogenic influence on extreme climate events
# mongoed: optimal policies for observing time series and related restless bandit  problems
# mongoed: data-mining research in education
# mongoed: network dependence testing via diffusion maps and distance-based  correlations
# mongoed: comments on `high-dimensional simultaneous inference with the bootstrap'
# mongoed: estimation of the average number of continuous crossings for  non-stationary non-diffusion processes
# mongoed: weak separablility for two-way functional data: concept and test
# mongoed: numerical gaussian processes for time-dependent and non-linear partial  differential equations
# mongoed: bayesian effect fusion for categorical predictors
# mongoed: predictive mean matching imputation in survey sampling
# mongoed: bayesian latent time joint mixed effect models for multicohort  longitudinal data
# mongoed: distance covariance for stochastic processes
# mongoed: quantifying uncertainty in transdimensional markov chain monte carlo  using discrete markov models
# Topic: stat, Skipping: 370
# mongoed: cdc: convolutional-de-convolutional networks for precise temporal action  localization in untrimmed videos
# mongoed: power control and relay selection in full-duplex cognitive relay  networks: coherent versus non-coherent scenarios
# mongoed: power allocation for full-duplex relay selection in underlay cognitive  radio networks: coherent versus non-coherent scenarios
# mongoed: using matching to detect infeasibility of some integer programs
# mongoed: secure count query on encrypted genomic data
# mongoed: guardian of the han: thwarting mobile attacks on smart-home devices  using os-level situation awareness
# mongoed: distributed partial clustering
# mongoed: l-graphs and monotone l-graphs
# mongoed: coded caching schemes with low rate and subpacketizations
# mongoed: deep-learning for classification of colorectal polyps on whole-slide  images
# mongoed: an unsupervised approach for discovering relevant tutorial fragments for  apis
# mongoed: a more accurate model for finding tutorial segments explaining apis
# mongoed: using graphs of classifiers to impose declarative constraints on  semi-supervised learning
# mongoed: detection of nonlinearly distorted ofdm signals via generalized  approximate message passing
# mongoed: perceiving and reasoning about liquids using fully convolutional  networks
# mongoed: towards implementation of cellular automata in microbial fuel cells
# mongoed: a unified bellman equation for causal information and value in markov  decision processes
# mongoed: on the vc-dimension of binary codes
# mongoed: graph sampling with determinantal processes
# mongoed: face alignment with cascaded semi-parametric deep greedy neural forests
# mongoed: how bad is selfish routing in practice?
# mongoed: doing things twice: strategies to identify studies for targeted  validation
# mongoed: magneto-inductive passive relaying in arbitrarily arranged networks
# Topic: cs, Skipping: 370
# mongoed: blind source separation of tensor-valued time series
# mongoed: proper bayes and minimax predictive densities for a matrix-variate  normal distribution
# mongoed: on bayesian exponentially embedded family for model order selection
# mongoed: the informativeness of $k$-means and dimensionality reduction for  learning mixture models
# mongoed: diving into the shallows: a computational perspective on large-scale  shallow learning
# mongoed: reliable decision support using counterfactual models
# mongoed: probabilistic mid- and long-term electricity price forecasting
# mongoed: intraoperative margin assessment of human breast tissue in optical  coherence tomography images using deep neural networks
# mongoed: bi-class classification of humpback whale sound units against complex  background noise with deep convolution neural network
# mongoed: the risk of machine learning
# mongoed: prediction of infectious disease epidemics via weighted density  ensembles
# mongoed: consistent estimation in cox proportional hazards model with measurement  errors and unbounded parameter set
# mongoed: catalyst acceleration for gradient-based non-convex optimization
# mongoed: provably optimal algorithms for generalized linear contextual bandits
# mongoed: achieving non-discrimination in prediction
# mongoed: multi-sensor data pattern recognition for multi-target localization: a  machine learning approach
# mongoed: dual iterative hard thresholding: from non-convex sparse minimization to  non-smooth concave maximization
# mongoed: theoretical properties for neural networks with weight matrices of low  displacement rank
# mongoed: inertial odometry on handheld smartphones
# mongoed: phylogenetic tools in astrophysics
# mongoed: the statistical recurrent unit
# mongoed: sequence of purchases in credit card data reveal life styles in urban  populations
# mongoed: doubly accelerated stochastic variance reduced dual averaging method for  regularized empirical risk minimization
# mongoed: fast k-nearest neighbour search via prioritized dci
# mongoed: learning to optimize neural nets
# Topic: stat, Skipping: 395
# mongoed: l2gsci: local to global seam cutting and integrating for accurate face  contour extraction
# mongoed: a theory of output-side unsupervised domain adaptation
# mongoed: improving regret bounds for combinatorial semi-bandits with  probabilistically triggered arms and its applications
# mongoed: neural machine translation and sequence-to-sequence models: a tutorial
# mongoed: automatic classification of cancerous tissue in laserendomicroscopy  images of the oral cavity using deep learning
# mongoed: greed works - online algorithms for unrelated machine stochastic  scheduling
# mongoed: conditional hardness for sensitivity problems
# mongoed: approximation algorithms for tsp with neighborhoods in the plane
# mongoed: end-to-end network delay guarantees for real-time systems using sdn
# mongoed: measuring affectiveness and effectiveness in software systems
# mongoed: faster-than-nyquist non-orthogonal frequency-division multiplexing for  visible light communications
# mongoed: a ptas for tsp with neighborhoods among fat regions in the plane
# mongoed: fair allocation of indivisible goods to asymmetric agents
# mongoed: pneumatic modelling for adroit manipulation platform
# mongoed: reasoning about liquids via closed-loop simulation
# mongoed: effect of adaptive and cooperative adaptive cruise control on throughput  of signalized arterials
# mongoed: segicp: integrated deep semantic segmentation and pose estimation
# mongoed: diversified texture synthesis with feed-forward networks
# mongoed: controlling for unobserved confounds in classification using  correlational constraints
# mongoed: reducing guesswork via an unreliable oracle
# mongoed: learn-and-adapt stochastic dual gradients for network resource  allocation
# mongoed: data-dependent stability of stochastic gradient descent
# mongoed: multi-objective non-parametric sequential prediction
# mongoed: a/d converter architectures for energy-efficient vision processor
# Topic: cs, Skipping: 395
# mongoed: optnet: differentiable optimization as a layer in neural networks
# mongoed: multidimensional sampling of isotropically bandlimited signals
# mongoed: moleculenet: a benchmark for molecular machine learning
# mongoed: positive-unlabeled learning with non-negative risk estimator
# mongoed: dynamic word embeddings for evolving semantic discovery
# mongoed: in search of an entity resolution oasis: optimal asymptotic sequential  importance sampling
# mongoed: introduction to nonnegative matrix factorization
# mongoed: adaptive matching for expert systems with uncertain task types
# mongoed: a dichotomy for sampling barrier-crossing events of random walks with  regularly varying tails
# mongoed: a note on conditional covariance matrices for elliptical distributions
# mongoed: a restaurant process mixture model for connectivity based parcellation  of the cortex
# mongoed: the m33 synoptic stellar survey. ii. mira variables
# Topic: stat, Skipping: 420
# mongoed: parameterized complexity of finding a spanning tree with minimum reload  cost diameter
# mongoed: refactoring legacy javascript code to use classes: the good, the bad and  the ugly
# mongoed: drawing planar graphs with few geometric primitives
# mongoed: word forms - not just their lengths- are optimized for efficient  communication
# mongoed: principles and examples of plausible reasoning and propositional  plausible logic
# mongoed: 4-dof tracking for robot fine manipulation tasks
# mongoed: optimization and analysis of wireless powered multi-antenna cooperative  systems
# mongoed: viewpoint selection for photographing architectures
# mongoed: third-person imitation learning
# mongoed: ad-hoc affectance-selective families for layer dissemination
# mongoed: wireless powered dual-hop multi-antenna relaying systems: impact of csi  and antenna correlation
# mongoed: sound-word2vec: learning word representations grounded in sounds
# mongoed: cats and captions vs. creators and the clock: comparing multimodal  content to context in predicting relative popularity
# mongoed: frequent query matching in dynamic data warehousing
# mongoed: surprise-based intrinsic motivation for deep reinforcement learning
# mongoed: trust-aware collaborative denoising auto-encoder for top-n  recommendation
# mongoed: building a regular decision boundary with deep networks
# mongoed: mean teachers are better role models: weight-averaged consistency  targets improve semi-supervised deep learning results
# mongoed: sample-level deep convolutional neural networks for music auto-tagging  using raw waveforms
# mongoed: all the people around me: face discovery in egocentric photo-streams
# mongoed: multi-level and multi-scale feature aggregation using pre-trained  convolutional neural networks for music auto-tagging
# mongoed: orthogonalized als: a theoretically principled tensor decomposition  algorithm for practical use
# mongoed: psum:peer-to-peer multimedia content distribution using  collusion-resistant fingerprinting
# Topic: cs, Skipping: 420
# mongoed: convex geometry of the generalized matrix-fractional function
# mongoed: evaluating graph signal processing for neuroimaging through  classification and dimensionality reduction
# mongoed: near-optimal closeness testing of discrete histogram distributions
# mongoed: a time series distance measure for efficient clustering of input output  signals by their underlying dynamics
# mongoed: neural episodic control
# mongoed: activation maximization generative adversarial nets
# mongoed: on the expressive power of overlapping architectures of deep learning
# mongoed: optimized cost per click in taobao display advertising
# mongoed: classification and clustering for samples of event time data using  non-homogeneous poisson process models
# mongoed: on the limits of learning representations with label-based supervision
# Topic: stat, Skipping: 445
# mongoed: all you need is beyond a good init: exploring better solution for  training extremely deep convolutional neural networks with orthonormality and  modulation
# mongoed: decomposable submodular function minimization: discrete and continuous
# mongoed: tight space-approximation tradeoff for the multi-pass streaming set  cover problem
# mongoed: approximation algorithms for maximin fair division
# mongoed: exploiting spontaneous transmissions for broadcasting and leader  election in radio networks
# mongoed: the parameterized space complexity of model-checking bounded variable  first-order logic
# mongoed: montgomery curves and their arithmetic
# mongoed: robust cooperative relay beamforming
# mongoed: a physarum-inspired model for the probit-based stochastic user  equilibrium problem
# mongoed: deep head pose estimation from depth data for in-car automotive  applications
# mongoed: on von schelling formula for the generalized coupon collector problem
# mongoed: co-evolutionary multi-task learning for dynamic time series prediction
# mongoed: a multitask diffusion strategy with optimized inter-cluster cooperation
# mongoed: approximate muscle guided beam search for three-index assignment problem
# mongoed: software engineers' information seeking behavior in change impact  analysis - an interview study
# mongoed: a proposal for ethically traceable artificial intelligence
# mongoed: neuromorphic hardware in the loop: training a deep spiking network on  the brainscales wafer-scale system
# mongoed: dimspan - transactional frequent subgraph mining with distributed  in-memory dataflow systems
# mongoed: joint pilot sequence design and power control for max-min fairness in  uplink massive mimo
# mongoed: high-resolution multispectral dataset for semantic segmentation
# mongoed: exchangeable choice functions
# Topic: cs, Skipping: 445
# mongoed: the maximum likelihood degree of toric varieties
# mongoed: deep robust kalman filter
# mongoed: convolutional recurrent neural networks for bird audio detection
# mongoed: on conditional least squares estimation for affine diffusions based on  continuous time observations
# mongoed: global weisfeiler-lehman graph kernels
# mongoed: on structured prediction theory with calibrated convex surrogate losses
# mongoed: an investigation into machine learning approaches for forecasting  spatio-temporal demand in ride-hailing service
# mongoed: data-driven estimation of mutual information between dependent data
# mongoed: online multilinear dictionary learning for sequential compressive  sensing
# mongoed: faster coordinate descent via adaptive importance sampling
# mongoed: online learning to rank in stochastic click models
# mongoed: regularising non-linear models using feature side-information
# mongoed: customer lifetime value prediction using embeddings
# mongoed: online convex optimization with unconstrained domains and losses
# mongoed: exploiting strong convexity from data with primal-dual first-order  algorithms
# mongoed: on sampling from massive graph streams
# mongoed: online learning without prior information
# mongoed: cost-optimal learning of causal graphs
# mongoed: structural data recognition with graph model boosting
# mongoed: byzantine-tolerant machine learning
# mongoed: introduction to formal concept analysis and its applications in  information retrieval and related fields
# mongoed: model-based policy search for automatic tuning of multivariate pid  controllers
# mongoed: deep bayesian active learning with image data
# mongoed: dropout inference in bayesian neural networks with alpha-divergences
# Topic: stat, Skipping: 470
# mongoed: on the complexity of enumeration
# mongoed: context-based concurrent experience sharing in multiagent systems
# mongoed: random triggering based sub-nyquist sampling system for sparse multiband  signal
# mongoed: distributed exact shortest paths in sublinear time
# mongoed: point-cloud-based aerial fragmentation analysis for application in the  minerals industry
# mongoed: metric learning for generalizing spatial relations to new objects
# mongoed: efficient strategy computation in zero-sum asymmetric repeated games
# mongoed: 5g wireless and wired convergence in a passive optical network using  uf-ofdm and gfdm
# mongoed: an lp approach for solving two-player zero-sum repeated bayesian games
# mongoed: network inference via the time-varying graphical lasso
# mongoed: autopass: an automatic password generator
# mongoed: a new belief markov chain model and its application in inventory  prediction
# mongoed: concentration bounds for high sensitivity functions through differential  privacy
# mongoed: evidential supplier selection based on interval data fusion
# mongoed: mesh-to-raster based non-rigid registration of multi-modal images
# mongoed: symbolic solutions of simultaneous first-order pdes in one unknown
# mongoed: the fog makes sense: enabling social sensing services with limited  internet connectivity
# mongoed: incorporating the knowledge of dermatologists to convolutional neural  networks for the diagnosis of skin lesions
# mongoed: learning from experience: a dynamic closed-loop qoe optimization for  video adaptation and delivery
# mongoed: model reduction for aperiodically sampled data systems
# mongoed: fairplay: fraud and malware detection in google play
# mongoed: scaling in internet traffic: a 14 year and 3 day longitudinal study,  with multiscale analyses and random projections
# Topic: cs, Skipping: 470
# mongoed: parallel implementation of efficient search schemes for the inference of  cancer progression models
# mongoed: a gamp based low complexity sparse bayesian learning algorithm
# mongoed: sample efficient feature selection for factored mdps
# mongoed: decorrelated jet substructure tagging using adversarial neural networks
# mongoed: strong convergence rates of probabilistic integrators for ordinary  differential equations
# mongoed: right for the right reasons: training differentiable models by  constraining their explanations
# mongoed: recovery of sparse and low rank components of matrices using iterative  method with adaptive thresholding
# mongoed: deep learning in customer churn prediction: unsupervised feature  learning on abstract company independent feature vectors
# mongoed: segmentation of skin lesions based on fuzzy classification of pixels and  histogram thresholding
# mongoed: prostate cancer diagnosis using deep learning with 3d multiparametric  mri
# mongoed: sequential local learning for latent graphical models
# mongoed: multiscale hierarchical convolutional networks
# mongoed: robustness from structure: inference with hierarchical spiking networks  on analog neuromorphic hardware
# mongoed: continual learning through synaptic intelligence
# mongoed: poisson multi-bernoulli mixture filter: direct derivation and  implementation
# mongoed: langevin dynamics with continuous tempering for training deep neural  networks
# mongoed: generalized self-concordant functions: a recipe for newton-type methods
# mongoed: deriving optimal weights in deep neural networks
# mongoed: discriminate-and-rectify encoders: learning from image transformation  sets
# mongoed: online learning rate adaptation with hypergradient descent
# mongoed: learned optimizers that scale and generalize
# mongoed: assumption-free and near-optimal sparse inverse covariance selection
# mongoed: riemannian stochastic quasi-newton algorithm with variance reduction and  its convergence analysis
# mongoed: resilience: a criterion for learning in the presence of arbitrary  outliers
# mongoed: matched bipartite block model with covariates
# Topic: stat, Skipping: 495
# mongoed: wireless channel estimation with low-complexity 1-bit adc and unknown  quantization threshold
# mongoed: learning across scales - a multiscale method for convolution neural  networks
# mongoed: sok: cryptographically protected database search
# mongoed: game-theoretic investigation of intensional equalities
# mongoed: fast back-projection for non-line of sight reconstruction
# mongoed: combining self-supervised learning and imitation for vision-based rope  manipulation
# mongoed: performing stance detection on twitter data using computational  linguistics techniques
# mongoed: distributed beamforming with wirelessly powered relay nodes
# mongoed: random vector generation of a semantic space
# mongoed: direct white matter bundle segmentation using stacked u-nets
# mongoed: performance analysis for time-of-arrival estimation with oversampled  low-complexity 1-bit a/d conversion
# mongoed: robust motion planning employing signal temporal logic
# mongoed: a lattice formulation of the f4 completion procedure
# mongoed: auto-context convolutional neural network (auto-net) for brain  extraction in magnetic resonance imaging
# mongoed: the feasibility of dynamically granted permissions: aligning mobile  privacy with user preferences
# mongoed: the impact of road configuration on v2v-based cooperative localization
# mongoed: guarantees for greedy maximization of non-submodular functions with  applications
# mongoed: leveling the playing field for visually impaired using transport  assistant
# mongoed: evaluation of machine learning methods to predict coronary artery  disease using metabolomic data
# mongoed: theory morphisms in church's type theory with quotation and evaluation
# mongoed: computing in memory with spin-transfer torque magnetic ram
# mongoed: non-line-of-sight tracking of people at long range
# Topic: cs, Skipping: 495
# mongoed: classification of copd with multiple instance learning
# mongoed: transfer learning by asymmetric image weighting for segmentation across  scanners
# ...
# mongoed: aggregation of classifiers: a justifiable information granularity  approach
# mongoed: efficient online learning for optimizing value of information: theory  and application to interactive troubleshooting
# mongoed: model selection and parameter inference in phylogenetics using nested  sampling
# mongoed: steganographic generative adversarial networks
# mongoed: shift aggregate extract networks
# mongoed: the nature and origin of heavy tails in retweet activity
# mongoed: low-rank and sparse nmf for joint endmembers' number estimation and  blind unmixing of hyperspectral images
# mongoed: conditional accelerated lazy stochastic gradient descent
# mongoed: pattern representation and recognition with accelerated analog  neuromorphic systems
# mongoed: deep sets
# mongoed: curriculum dropout
# mongoed: sim-ce: an advanced simulink platform for studying the brain of  caenorhabditis elegans
# mongoed: an automated auto-encoder correlation-based health-monitoring and  prognostic method for machine bearings
# mongoed: deep tensor encoding
# mongoed: fully symmetric kernel quadrature
# mongoed: dynamic information acquisition from multiple sources
# mongoed: bernoulli rank-$1$ bandits for click feedback
# mongoed: a preferential attachment paradox: how preferential attachment combines  with growth to produce networks with log-normal in-degree distributions
# Topic: stat, Skipping: 520
# mongoed: demand estimation and chance-constrained fleet management for ride  hailing
# mongoed: scalable underapproximation for the stochastic reach-avoid problem for  high-dimensional lti systems using fourier transforms
# mongoed: english conversational telephone speech recognition by humans and  machines
# mongoed: asymptotically optimal stochastic encryption for quantized sequential  detection in the presence of eavesdroppers
# mongoed: contextual motifs: increasing the utility of motifs using contextual  data
# mongoed: dynamic arrival rate estimation for campus mobility on demand network  graphs
# mongoed: decentralized consistent network updates in sdn with ez-segway
# mongoed: an optimal hierarchical clustering approach to segmentation of mobile  lidar point clouds
# mongoed: commutative positive varieties of languages
# mongoed: distance metric learning using graph convolutional networks: application  to functional brain networks
# mongoed: a policy model and framework for context-aware access control to  information resources
# mongoed: building a syllable database to solve the problem of khmer word  segmentation
# mongoed: deep view morphing
# mongoed: covert communication in fading channels under channel uncertainty
# mongoed: using deep learning method for classification: a proposed algorithm for  the isic 2017 skin lesion classification challenge
# mongoed: a gentle introduction to epistemic planning: the del approach
# mongoed: deterministic temporal logics and interval constraints
# mongoed: finite model reasoning in expressive fragments of first-order logic
# mongoed: temporal justification logic
# mongoed: cooperative epistemic multi-agent planning for implicit coordination
# mongoed: graphical sequent calculi for modal logics
# mongoed: stealthy malware traffic - not as innocent as it looks
# Topic: cs, Skipping: 520
# mongoed: the same analysis approach: practical protection against the pitfalls of  novel neuroimaging analysis methods
# mongoed: qmdp-net: deep learning for planning under partial observability
# mongoed: independence clustering (without a matrix)
# mongoed: on the use of default parameter settings in the empirical evaluation of  classification algorithms
# mongoed: guaranteed sufficient decrease for variance reduced stochastic gradient  descent
# mongoed: on the limitation of convolutional neural networks in recognizing  negative images
# mongoed: dance dance convolution
# mongoed: ensemble representation learning: an analysis of fitness and survival  for wrapper-based genetic programming methods
# mongoed: metalearning for feature selection
# mongoed: cross-modal deep metric learning with multi-task regularization
# mongoed: nonparametric variational auto-encoders for hierarchical representation  learning
# mongoed: high-resolution breast cancer screening with multi-view deep  convolutional neural networks
# mongoed: knowledge distillation using unlabeled mismatched images
# mongoed: zm-net: real-time zero-shot image manipulation network
# mongoed: sequential detection of three-dimensional signals under dependent noise
# mongoed: phytoplankton hotspot prediction with an unsupervised spatial community  model
# mongoed: an army of me: sockpuppets in online discussion communities
# mongoed: rebar: low-variance, unbiased gradient estimates for discrete latent  variable models
# mongoed: maximum a posteriori estimation through simulated annealing for binary  asteroid orbit determination
# mongoed: episode-based active learning with bayesian neural networks
# mongoed: a probabilistic approach to emission-line galaxy classification
# mongoed: clustering for different scales of measurement - the gap-ratio weighted  k-means algorithm
# Topic: stat, Skipping: 545
# mongoed: a covert data transport protocol
# mongoed: certificate transparency with privacy
# mongoed: no-but-semantic-match: computing semantically matched xml keyword search  results
# mongoed: removal of salt and pepper noise from gray-scale and color images: an  adaptive approach
# mongoed: influence of random opinion change in complex networks
# mongoed: space-efficient k-mer algorithm for generalized suffix tree
# mongoed: what makes a good app description?
# mongoed: functions that emerge through end-to-end reinforcement learning - the  direction for artificial general intelligence -
# mongoed: shape dna: basic generating functions for geometric moment invariants
# mongoed: srn: side-output residual network for object symmetry detection in the  wild
# mongoed: open set intrusion recognition for fine-grained attack categorization
# mongoed: design of the artificial: lessons from the biological roots of general  intelligence
# mongoed: fault tolerant leader election in distributed systems
# mongoed: automated u.s diplomatic cables security classification: topic model  pruning vs. classification based on clusters
# mongoed: on the emotion of users in app reviews
# mongoed: an annotated bibliography on 1-planarity
# mongoed: x-ray astronomical point sources recognition using granular binary-tree  svm
# mongoed: on model predictive path following and trajectory tracking for  industrial robots
# mongoed: using approximate computing for the calculation of inverse matrix p-th  roots
# mongoed: on the deployment of distributed antennas for wireless power transfer  with safety electromagnetic radiation level requirement
# mongoed: triple generative adversarial nets
# mongoed: the formal semantics of rascal light
# mongoed: heterogeneous information network model for equipment-standard system
# Topic: cs, Skipping: 545
# mongoed: characterization of deterministic and probabilistic sampling patterns  for finite completability of low tensor-train rank tensor
# mongoed: unifying pac and regret: uniform pac bounds for episodic reinforcement  learning
# mongoed: direct acoustics-to-word models for english conversational speech  recognition
# mongoed: empirical risk minimization as parameter choice rule for general linear  regularization methods
# mongoed: randomized kernel methods for least-squares support vector machines
# mongoed: how to avoid the curse of dimensionality: scalability of particle  filters with and without importance weights
# mongoed: self corrective perturbations for semantic segmentation and  classification
# mongoed: unsupervised basis function adaptation for reinforcement learning
# mongoed: fast stochastic variance reduced gradient method with momentum  acceleration for machine learning
# mongoed: quantifying and suppressing ranking bias in a large citation network
# mongoed: mse estimates for multitaper spectral estimation and off-grid  compressive sensing
# mongoed: improved nn-jpdaf for joint multiple target tracking and feature  extraction
# mongoed: a nonconvex splitting method for symmetric nonnegative matrix  factorization: convergence analysis and optimality
# mongoed: smart augmentation - learning an optimal data augmentation strategy
# mongoed: asymmetric learning vector quantization for efficient nearest neighbor  classification in dynamic time warping spaces
# mongoed: stochastic methods for composite optimization problems
# mongoed: sequence-to-sequence models can directly translate foreign speech
# mongoed: exploration--exploitation in mdps with options
# mongoed: count-ception: counting by fully convolutional redundant counting
# mongoed: solving sdps for synchronization and maxcut problems via the  grothendieck inequality
# mongoed: uncertainty quantification in graph-based classification of high  dimensional data
# mongoed: token-based function computation with memory
# mongoed: exact and approximate limit behaviour of the yule tree's cophenetic  index
# mongoed: randomized cp tensor decomposition
# Topic: stat, Skipping: 570
# mongoed: linear and circular microphone array for remote surveillance: simulated  performance analysis
# mongoed: gaussian multiple access channels with one-bit quantizer at the receiver
# mongoed: robust whole-body motion control of legged robots
# mongoed: performance analysis of near-optimal energy buffer aided wireless  powered communication
# mongoed: the minimum shared edges problem on grid-like graphs
# mongoed: effects of faults, experience, and personality on trust in a robot  co-worker
# mongoed: a scalable line-independent design algorithm for voltage and frequency  control in ac islanded microgrids
# mongoed: design and development of an automated robotic pick & stow system for an  e-commerce warehouse
# mongoed: deep learning based large scale visual recommendation and search for  e-commerce
# mongoed: survivability improvement against earthquakes in backbone optical  networks using actual seismic zone information
# mongoed: on the family of 0/1-polytopes with np-complete non-adjacency relation
# mongoed: qualitative assessment of recurrent human motion
# mongoed: scientific outreach with teegi, a tangible eeg interface to talk about  neurotechnologies
# mongoed: vocabulary alignment in openly specified interactions
# mongoed: graph sketching-based space-efficient data clustering
# mongoed: assessing the privacy cost in centralized event-based demand response  for microgrids
# mongoed: a quantum dynamic belief decision making model
# mongoed: learning from noisy labels with distillation
# mongoed: using off-the-shelf exception support components in c++ verification
# mongoed: localization in long-range ultra narrow band iot networks using rssi
# mongoed: on time and consistency in multi-level agent-based simulations
# mongoed: reduced complexity optimal detection of binary faster-than-nyquist  signaling
# Topic: cs, Skipping: 570
# mongoed: adversarial source identification game with corrupted training
# mongoed: adaptive simulation-based training of ai decision-makers using bayesian  optimization
# mongoed: parameter estimation for fractional ornstein-uhlenbeck processes of  general hurst parameter
# mongoed: convergence of the forward-backward algorithm: beyond the worst case  with the help of geometry
# ---------------------------------------------------------------------------
# ConnectionRefusedError                    Traceback (most recent call last)
# ~/anaconda3/lib/python3.6/site-packages/pymongo/pool.py in connect(self)
#     499         try:
# --> 500             sock = _configured_socket(self.address, self.opts)
#     501             if self.handshake:
#
# ~/anaconda3/lib/python3.6/site-packages/pymongo/pool.py in _configured_socket(address, options)
#     425     """
# --> 426     sock = _create_connection(address, options)
#     427     ssl_context = options.ssl_context
#
# ~/anaconda3/lib/python3.6/site-packages/pymongo/pool.py in _create_connection(address, options)
#     409     if err is not None:
# --> 410         raise err
#     411     else:
#
# ~/anaconda3/lib/python3.6/site-packages/pymongo/pool.py in _create_connection(address, options)
#     402                             options.socket_keepalive)
# --> 403             sock.connect(sa)
#     404             return sock
#
# ConnectionRefusedError: [Errno 61] Connection refused
#
# During handling of the above exception, another exception occurred:
#
# AutoReconnect                             Traceback (most recent call last)
# <ipython-input-10-4491acc49858> in <module>()
#      55
#      56                     if article.article:
# ---> 57                         col.insert_one(article.mongo)
#      58                         print('mongoed: '+article.title)
#      59
#
# ~/anaconda3/lib/python3.6/site-packages/pymongo/collection.py in insert_one(self, document, bypass_document_validation)
#     620         if not (isinstance(document, RawBSONDocument) or "_id" in document):
#     621             document["_id"] = ObjectId()
# --> 622         with self._socket_for_writes() as sock_info:
#     623             return InsertOneResult(
#     624                 self._insert(sock_info, document,
#
# ~/anaconda3/lib/python3.6/contextlib.py in __enter__(self)
#      79     def __enter__(self):
#      80         try:
# ---> 81             return next(self.gen)
#      82         except StopIteration:
#      83             raise RuntimeError("generator didn't yield") from None
#
# ~/anaconda3/lib/python3.6/site-packages/pymongo/mongo_client.py in _get_socket(self, selector)
#     716         server = self._get_topology().select_server(selector)
#     717         try:
# --> 718             with server.get_socket(self.__all_credentials) as sock_info:
#     719                 yield sock_info
#     720         except NetworkTimeout:
#
# ~/anaconda3/lib/python3.6/contextlib.py in __enter__(self)
#      79     def __enter__(self):
#      80         try:
# ---> 81             return next(self.gen)
#      82         except StopIteration:
#      83             raise RuntimeError("generator didn't yield") from None
#
# ~/anaconda3/lib/python3.6/site-packages/pymongo/server.py in get_socket(self, all_credentials, checkout)
#     150     @contextlib.contextmanager
#     151     def get_socket(self, all_credentials, checkout=False):
# --> 152         with self.pool.get_socket(all_credentials, checkout) as sock_info:
#     153             yield sock_info
#     154
#
# ~/anaconda3/lib/python3.6/contextlib.py in __enter__(self)
#      79     def __enter__(self):
#      80         try:
# ---> 81             return next(self.gen)
#      82         except StopIteration:
#      83             raise RuntimeError("generator didn't yield") from None
#
# ~/anaconda3/lib/python3.6/site-packages/pymongo/pool.py in get_socket(self, all_credentials, checkout)
#     537         # First get a socket, then attempt authentication. Simplifies
#     538         # semaphore management in the face of network errors during auth.
# --> 539         sock_info = self._get_socket_no_auth()
#     540         try:
#     541             sock_info.check_auth(all_credentials)
#
# ~/anaconda3/lib/python3.6/site-packages/pymongo/pool.py in _get_socket_no_auth(self)
#     575             if from_pool:
#     576                 # Can raise ConnectionFailure.
# --> 577                 sock_info = self._check(sock_info)
#     578
#     579         except:
#
# ~/anaconda3/lib/python3.6/site-packages/pymongo/pool.py in _check(self, sock_info)
#     625             return sock_info
#     626         else:
# --> 627             return self.connect()
#     628
#     629     def _raise_wait_queue_timeout(self):
#
# ~/anaconda3/lib/python3.6/site-packages/pymongo/pool.py in connect(self)
#     510             if sock is not None:
#     511                 sock.close()
# --> 512             _raise_connection_failure(self.address, error)
#     513
#     514     @contextlib.contextmanager
#
# ~/anaconda3/lib/python3.6/site-packages/pymongo/pool.py in _raise_connection_failure(address, error)
#      63         raise NetworkTimeout(msg)
#      64     else:
# ---> 65         raise AutoReconnect(msg)
#      66
#      67
#
# AutoReconnect: localhost:12345: [Errno 61] Connection refused
